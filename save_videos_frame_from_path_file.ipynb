# %%
import os
import os.path
import cv2
print("opencv version is:{}".format(cv2.__version__))
import pytesseract
from PIL import Image
import pandas as pd
from os import listdir
import seaborn as sns
import matplotlib as plt
from matplotlib import image
from matplotlib import pyplot
from numpy import asarray
import numpy as np
# Out:
# opencv version is:4.5.5

# %%
# list videofiles
os.chdir("/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/")
directory = 'videos'
directories = os.listdir(directory)
directories

# %%
# convert list(videofiles) into txt file
with open('videos.txt', 'w') as f:
    for path in directories:
        f.write('{}/{}'.format(directory,path))
        f.write('\n')

# %%
import cv2
img = cv2.imread('/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/screencast_videos1/AirspeedValues_1000.avi/1_AirspeedValues_1000.avi.jpeg')
print(img.shape) # Print image shape
#cv2.imshow("original", img)
# Cropping an image
cropped_image = img[490:570, 1130:1200]
# Display cropped image
cv2.imshow("cropped", cropped_image)
# Save the cropped image
cv2.imwrite("cropped.jpg", cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()
cv2.destroyAllWindows()

# %%
from os import listdir
folder_dir = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/screencast_videosediting"
path = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/2croppedscreencast_videosediting"
os.makedirs(path)

for images in os.listdir(folder_dir):
    if (images.endswith(".jpeg")):
        img = cv2.imread(images)
        cropped_image = img[490:570, 1130:1200]
        print("hello")
        cv2.imwrite(os.path.join(path , images), cropped_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Frame annotation
extracted = []
# Defining paths to tesseract.exe
path_to_tesseract = r'/Users/kavya/opt/anaconda3/envs/tesseract/bin/tesseract'
pytesseract.pytesseract.tesseract_cmd = path_to_tesseract
directory = '/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/screencast_videosediting/test.mp4'
imgdirect = []
for filename in os.listdir(directory):
    if filename.endswith(".jpeg"):
        with open(os.path.join(directory, filename)) as input_file:
            # change directory, open and read image 
            os.chdir(r"/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/screencast_videosediting/test.mp4")
            path = os.path.split(filename)[1]
            img = Image.open(path, "r")
            text = pytesseract.image_to_string(img)
            
            # removing unnecessary characters and spaces 
            #processed = text[0:11].rstrip()
            
            # adding four hours to change time zone
            #first = int(processed[:2])
            #zone = zone + 4
                #print(zone)
            #processed = processed.replace(processed[:2], str(zone))
                #processed = processed[0:2] + replacement + sample_str[n+1: ]
                # store all extracted text in an array
            if text != "":
                extracted.append(text)
                imgdirect.append(filename)
                
            #print(path + " " + text + " " + processed)
random = pd.DataFrame()
random["Extracted"] = extracted
random["Image Name"] = imgdirect
random.to_csv('/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/random.csv')

# %%
print(len(extracted))
print(len(imgdirect))

# %%
extracted[1].rstrip()
print(extracted[1])

# %%
print(len(imgdirect))

# %%
new = extracted[1]
print(new)
hello = new[23:33].rstrip()
print(hello)

# %%
zone = int(hello[:2])
zone = zone + 4
print(zone)
hello = hello.replace(hello[:2], str(zone))
print(hello)

# %%
df = pd.read_csv("/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/Airspeed.csv")
df.drop(df.columns.difference(['Timestamp','True Airspeed(kn)']), 1, inplace=True)
df['True Airspeed(kn)'] = pd.to_numeric(df['True Airspeed(kn)'])
df

# %%
df.drop( df[ df['True Airspeed(kn)'] < 35 ].index , inplace=True)
df['True Airspeed(kn)'] = round(df['True Airspeed(kn)'])
timestamp = []
for i in df.Timestamp:
    timestamp.append(i[: -3])
df["Timestamp"] = timestamp
print(df)
df.to_csv('/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/correctfinaldataextract.csv')

# %%
#crop images 

folder_dir = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/screencast_videosediting/test.mp4"
video_frame_path = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/newcroppedscreencast_videosediting"
path = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/screencast_videosediting/test.mp4"
os.makedirs(video_frame_path)
id = 0
for images in os.listdir(folder_dir):
    # check if the image end swith png or jpg or jpeg
    if (images.endswith(".jpeg")):
        print("hello")
        img = cv2.imread(os.path.join(path, images))
        cropped_image = img[490:570, 1130:1200]
        cv2.imwrite("{0}/{1}_{2}.jpeg".format(video_frame_path, id, "test.mp4"), cropped_image)
        id = id + 1



cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
import seaborn as sns
import matplotlib as plt
image_path = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/croppedscreencast_videos8/0_AirspeedValues_1000.jpeg"
img = = cv2.imread(image_path)
img = img/255

plt.figure(figsize=(30,30))
sns.heatmap(img, annot= True, cmap="binary")

# %%
extime = pd.read_csv("random.csv")
extracted = extime["Extracted"]
print(len(extracted))
imgdirect = extime["Image Name"]
print(len(imgdirect))

# %%
final = []
imgnew = []
for x in range(0,3272):
    hello = extracted[x]
    helloimg = imgdirect[x]
    new = hello.rstrip()
    cleaned = new[23:33].rstrip()

    try:
        zone = int(cleaned[:2])
        zone = zone + 4
        if zone > 12:
            zone = zone - 12
            i = cleaned.replace(cleaned[:2], str(zone))
            print(i)
            final.append(i)
            imgnew.append(helloimg)
    except:
        print("none")

# %%
print(len(final))
print(len(imgnew))

# %%
new = pd.DataFrame()
new["Image"] = imgnew
new["Extracted Timestamp"] = final
new.to_csv('/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/finaltimestamps.csv')

# %%
print(nwdf)

# %%
df1 = pd.read_csv("correctfinaldataextract.csv") #csv with airspeed values
giventime = df1["Timestamp"]
givenair = df1["True Airspeed(kn)"]

df2 = pd.read_csv("finaltimestamps.csv")
extractedimg = df2["Image"]
extractedtime = df2["Extracted Timestamp"]

# %%
print(extractedtime[0])

# %%
print(len(giventime))
print(len(givenair))
print(len(extractedimg))
print(len(extractedtime))

# %%
print(matchedspeed[0])
print(matchedimage[0])

# %%
print(final[1])

# %%
matchedspeed = []
matchedimage = []
# analyzed["Airspeed"] = 
for i in range(0,2982):
    index = df1.index[(df1['Timestamp'] == extractedtime[i])]
    #print(index)
    if index >= 0:
        #print("Hello")
        print("yes")
        ind = df1.index[(df1['Timestamp'] == extractedtime[i])][0]
        #index = df1[df1['Timestamp'] == extractedtime[i]].index()
        new = df1.iat[ind,2]
        #print(new)
        #print(index)
        #df.loc[df["Timetstamp"] = ]
        matchedspeed.append(new)
        matchedimage.append(extractedimg[i])
    else:
        print("no")
        #matchedspeed.append("none")

# %%
print(len(matchedspeed))
print(len(matchedimage))

# %%
mapped = pd.DataFrame()
mapped["Image Nmae"] = matchedimage
mapped["Airspeed Value"] = matchedspeed

# %%
print(mapped)

# %%
mapped.to_csv("/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/imagestimestamp.csv")
#VERY IMPORTANT

# %%
# remove pm in csv (works)
#timestamp = []
#for i in df.Timestamp:
    #timestamp.append(i[: -3])
#df["Timestamp"] = timestamp

# %%
# bar chart plot of a categorical variable
from pandas import read_csv
from seaborn import countplot
from matplotlib import pyplot
sns.set(rc={'figure.figsize':(900,150)})
sns.set(font_scale = 20)

# load the dataset
dataset = read_csv("/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/imagestimestamp.csv")
# create bar chart plot
countplot(x= "Airspeed Value", data=dataset)
# show plot
pyplot.show()

# %%
folder_dir = "/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/newcroppedscreencast_videosediting"
for images in os.listdir(folder_dir):
    image = Image.open('0_test.mp4.jpeg')
    pixels = asarray(image)
    # convert from integers to floats
    pixels = pixels.astype('float32')
    # normalize to the range 0-1
    pixels /= 255.0
    # confirm the normalization
    print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
# Out:
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# Min: 0.000, Max: 0.765
# ...

# %%
df = pd.read_csv("/Users/kavya/PycharmProjects/Helicopter Airspeed Value Prediction/imagestimestamp.csv")
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    print(len(train))
    print(len(validate))
    print(len(test))
train_validate_test_split(df)
# Out:
# 1621
# 540
# 542

# %%
# Steps for next week
# 1. Map timestamps
# 2. Make a count plot to visualize distribution 
# 3. Load, Normalize, and standardize images for training 
#correctfinaldataextract, finaltimestamps
